# %% [markdown]
# # 📒 Notebook : 07_checks_tables
#
# ---
#
# ## 📝 Objectif
#
# - Lister les tables, les colonnes de chaque table et tester les jointures sémantiques.
# - Statistiques et checks rapides.
# - Permettre la requête SQL directe sur les dimension et la table des faits.
#
# ---
#
# ## 👤 Auteur(s) / Contact
#
# - SEKARI Inès — [ines.sekari@efrei.net]
# - NKUIDA Malaïka - [malaika.nkuida@efrei.net]
#
# ---
#
# ## 🗓️ Versioning & Mise à jour
#
# | Version | Date        | Modifications                          |
# |---------|-------------|----------------------------------------|
# | 1.0     | 2025-05-05  | Création du script de vérification des tables        |

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_hopital LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 034b6559-55e9-4a1a-a504-bae37f65f887)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_maladie LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 2ea3d5c5-355e-4f27-8644-615804728b6f)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_medicament LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 607c2efc-72a9-4fa2-9f24-ee7d98b8097b)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_motif_admission LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 69a77933-7a89-40d8-9d86-9dad8cab1512)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_patient LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 732abfe1-262f-4980-bbc0-b2f4ae24637d)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_dim_temps LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a89753fd-1f31-4a4f-bcae-5f2e2098bcd2)

# %%
df = spark.sql("SELECT * FROM Health_lakehouse.gold_fact_consultation LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ae825166-2348-4898-9fbe-bf6c1f578e74, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 90427e02-19d9-440c-9e14-304ca176675e)

# %%
spark.sql("SHOW TABLES IN health_lakehouse").show(truncate=False)

tables = [
    "gold_dim_patient",
    "gold_dim_maladie",
    "gold_dim_hopital",
    "gold_dim_temps",
    "gold_dim_medicament",
    "gold_dim_motif_admission",
    "gold_fact_consultation",
]

for t in tables:
    print(f"\n===== Schéma de {t} =====")
    spark.sql(f"DESCRIBE TABLE Health_lakehouse.{t}").show(truncate=False)

spark.sql("""
SELECT f.consultation_id, f.patient_id, h.hopital_name
FROM Health_lakehouse.gold_fact_consultation f
LEFT JOIN Health_lakehouse.gold_dim_hopital h ON f.hopital_nom = h.hopital_id
LIMIT 10
""").show()

for t in tables:
    print(f"\nTable: {t}")
    spark.sql(f"SELECT COUNT(*) FROM health_lakehouse.{t}").show()
    # Optionnel : afficher les 5 premières lignes
    spark.sql(f"SELECT * FROM health_lakehouse.{t} LIMIT 5").show()
# Out:
# StatementMeta(, b62436fd-7230-44d2-97b1-4b9e3fac2ecf, 11, Finished, Available, Finished)
# +----------------+------------------------+-----------+
# |namespace       |tableName               |isTemporary|
# +----------------+------------------------+-----------+
# |health_lakehouse|bronze_maladie          |false      |
# |health_lakehouse|bronze_icd_code         |false      |
# |health_lakehouse|bronze_medicament       |false      |
# |health_lakehouse|bronze_motif_admission  |false      |
# |health_lakehouse|bronze_patient          |false      |
# |health_lakehouse|bronze_meds_code        |false      |
# |health_lakehouse|bronze_motifs_code      |false      |
# |health_lakehouse|silver_icd_code         |false      |
# |health_lakehouse|silver_meds_code        |false      |
# |health_lakehouse|silver_motifs_code      |false      |
# |health_lakehouse|silver_hopital          |false      |
# |health_lakehouse|gold_dim_patient        |false      |
# |health_lakehouse|gold_dim_maladie        |false      |
# |health_lakehouse|gold_dim_medicament     |false      |
# |health_lakehouse|gold_dim_hopital        |false      |
# |health_lakehouse|gold_dim_temps          |false      |
# |health_lakehouse|gold_dim_motif_admission|false      |
# |health_lakehouse|gold_fact_consultation  |false      |
# +----------------+------------------------+-----------+
#
#
# ===== Schéma de gold_dim_patient =====
# +----------------+---------+-------+
# |col_name        |data_type|comment|
# +----------------+---------+-------+
# |patient_id      |bigint   |NULL   |
# |hopital_nom     |string   |NULL   |
# |age             |int      |NULL   |
# |gender          |string   |NULL   |
# |profile_id      |string   |NULL   |
# |consultation_id |int      |NULL   |
# |ethnicity       |string   |NULL   |
# |race            |string   |NULL   |
# |lang            |string   |NULL   |
# |religion        |string   |NULL   |
# |maritalstatus   |string   |NULL   |
# |employstatus    |string   |NULL   |
# |insurance_status|string   |NULL   |
# |disposition     |string   |NULL   |
# |arrivalmode     |string   |NULL   |
# |previousdispo   |string   |NULL   |
# |n_surgeries     |int      |NULL   |
# |n_edvisits      |int      |NULL   |
# |n_admissions    |int      |NULL   |
# |timestamp_id    |string   |NULL   |
# +----------------+---------+-------+
#
#
# ===== Schéma de gold_dim_maladie =====
# +------------------+---------+-------+
# |col_name          |data_type|comment|
# +------------------+---------+-------+
# |consultation_id   |int      |NULL   |
# |maladie           |string   |NULL   |
# |patient_id        |bigint   |NULL   |
# |Code_CIM-10       |string   |NULL   |
# |Catégorie_médicale|string   |NULL   |
# |Description       |string   |NULL   |
# +------------------+---------+-------+
#
#
# ===== Schéma de gold_dim_hopital =====
# +---------------+---------+-------+
# |col_name       |data_type|comment|
# +---------------+---------+-------+
# |consultation_id|int      |NULL   |
# |patient_id     |bigint   |NULL   |
# |hopital_id     |string   |NULL   |
# |hopital_name   |string   |NULL   |
# +---------------+---------+-------+
#
#
# ===== Schéma de gold_dim_temps =====
# +---------------+---------+-------+
# |col_name       |data_type|comment|
# +---------------+---------+-------+
# |timestamp_id   |string   |NULL   |
# |year           |int      |NULL   |
# |month_num      |int      |NULL   |
# |day            |string   |NULL   |
# |month          |string   |NULL   |
# |weekday        |int      |NULL   |
# |arrivalhour_bin|string   |NULL   |
# |hour_bin_start |int      |NULL   |
# |hour_bin_end   |int      |NULL   |
# +---------------+---------+-------+
#
#
# ===== Schéma de gold_dim_medicament =====
# +--------------------+---------+-------+
# |col_name            |data_type|comment|
# +--------------------+---------+-------+
# |consultation_id     |int      |NULL   |
# |medicament          |string   |NULL   |
# |patient_id          |bigint   |NULL   |
# |medicament_label    |string   |NULL   |
# |classe_therapeutique|string   |NULL   |
# +--------------------+---------+-------+
#
#
# ===== Schéma de gold_dim_motif_admission =====
# +------------------+---------+-------+
# |col_name          |data_type|comment|
# +------------------+---------+-------+
# |consultation_id   |int      |NULL   |
# |motif_admission   |string   |NULL   |
# |patient_id        |bigint   |NULL   |
# |Catégorie_motif   |string   |NULL   |
# |Description_longue|string   |NULL   |
# +------------------+---------+-------+
#
#
# ===== Schéma de gold_fact_consultation =====
# +---------------------+-------------+-------+
# |col_name             |data_type    |comment|
# +---------------------+-------------+-------+
# |consultation_id      |int          |NULL   |
# |patient_id           |bigint       |NULL   |
# |hopital_nom          |string       |NULL   |
# |age                  |int          |NULL   |
# |gender               |string       |NULL   |
# |disposition          |string       |NULL   |
# |previousdispo        |string       |NULL   |
# |liste_maladie        |array<string>|NULL   |
# |liste_medicament     |array<string>|NULL   |
# |liste_motif_admission|array<string>|NULL   |
# |date_id              |string       |NULL   |
# |nb_chirurgies        |int          |NULL   |
# |nb_visited_urgences  |int          |NULL   |
# |nb_admissions        |int          |NULL   |
# +---------------------+-------------+-------+
#
# +---------------+-----------+------------+
# |consultation_id| patient_id|hopital_name|
# +---------------+-----------+------------+
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# |              1|68719476757|Hopital Beta|
# +---------------+-----------+------------+
#
#
# Table: gold_dim_patient
# +--------+
# |count(1)|
# +--------+
# |  560486|
# +--------+
#
# +----------+-----------+---+------+--------------------+---------------+------------------+--------------------+-------+-----------+-------------+------------+----------------+-----------+-----------+-------------+-----------+----------+------------+--------------------+
# |patient_id|hopital_nom|age|gender|          profile_id|consultation_id|         ethnicity|                race|   lang|   religion|maritalstatus|employstatus|insurance_status|disposition|arrivalmode|previousdispo|n_surgeries|n_edvisits|n_admissions|        timestamp_id|
# +----------+-----------+---+------+--------------------+---------------+------------------+--------------------+-------+-----------+-------------+------------+----------------+-----------+-----------+-------------+-----------+----------+------------+--------------------+
# |8589939807|          A| 50|  MALE|50_Male_Hispanic ...|             37|Hispanic or Latino|               Other|  Other|Pentecostal|     Divorced|Not Employed|        Medicaid|      Admit|  ambulance|    Discharge|          0|        13|           4|2016_April_Sunday...|
# |8589968628|          A| 32|  MALE|32_Male_Non-Hispa...|            342|      Non-Hispanic|  White or Caucasian|English|       None|       Single|   Full Time|        Medicaid|  Discharge|  ambulance|    Discharge|          0|         2|           0|2016_October_Thur...|
# |8589962016|          A| 27|FEMALE|27_Female_Non-His...|            349|      Non-Hispanic|Black or African ...|  Other|   Catholic|       Single|   Full Time|        Medicaid|  Discharge|  ambulance|    Discharge|          1|         7|           1|2014_November_Mon...|
# |8589936807|          B| 80|FEMALE|80_Female_Non-His...|            365|      Non-Hispanic|  White or Caucasian|English|       None|      Widowed|Not Employed|        Medicare|  Discharge|  ambulance|        Admit|          0|         1|           1|2015_January_Satu...|
# |8589953969|          B| 87|  MALE|87_Male_Non-Hispa...|            598|      Non-Hispanic|  White or Caucasian|English|   Catholic|      Married|     Retired|        Medicare|      Admit|  ambulance|    Discharge|          3|         0|           0|2016_September_Th...|
# +----------+-----------+---+------+--------------------+---------------+------------------+--------------------+-------+-----------+-------------+------------+----------------+-----------+-----------+-------------+-----------+----------+------------+--------------------+
#
#
# Table: gold_dim_maladie
# +--------+
# |count(1)|
# +--------+
# | 2428273|
# +--------+
#
# +---------------+-----------------+-----------+-----------+------------------+--------------------+
# |consultation_id|          maladie| patient_id|Code_CIM-10|Catégorie_médicale|         Description|
# +---------------+-----------------+-----------+-----------+------------------+--------------------+
# |             21|           anemia|68719481534|        D64|       Hématologie|              Anémie|
# |             24| anxietydisorders|68719481776|        F41|       Psychiatrie|    Troubles anxieux|
# |             24|              htn|68719481776|        I10|  domaine_clinique|Hypertension esse...|
# |             24|    mooddisorders|68719481776|        F32|       Psychiatrie|Troubles de l'humeur|
# |             24|ecodesunspecified|68719481776|        Y34|             Autre|Cause externe non...|
# +---------------+-----------------+-----------+-----------+------------------+--------------------+
#
#
# Table: gold_dim_hopital
# +--------+
# |count(1)|
# +--------+
# |  560486|
# +--------+
#
# +---------------+-----------+----------+-------------+
# |consultation_id| patient_id|hopital_id| hopital_name|
# +---------------+-----------+----------+-------------+
# |              1|68719476757|         B| Hopital Beta|
# |              2|68719477066|         C|Hopital Gamma|
# |              3|68719477082|         A|Hopital Alpha|
# |              4|68719477274|         A|Hopital Alpha|
# |              5|68719477328|         A|Hopital Alpha|
# +---------------+-----------+----------+-------------+
#
#
# Table: gold_dim_temps
# +--------+
# |count(1)|
# +--------+
# |    2016|
# +--------+
#
# +--------------------+----+---------+---------+---------+-------+---------------+--------------+------------+
# |        timestamp_id|year|month_num|      day|    month|weekday|arrivalhour_bin|hour_bin_start|hour_bin_end|
# +--------------------+----+---------+---------+---------+-------+---------------+--------------+------------+
# |2015_September_Sa...|2015|        9| Saturday|September|      6|          15-18|            15|          18|
# |2016_July_Wednesd...|2016|        7|Wednesday|     July|      3|          23-02|            23|           2|
# |2014_March_Saturd...|2014|        3| Saturday|    March|      6|          11-14|            11|          14|
# |2016_September_Mo...|2016|        9|   Monday|September|      1|          03-06|             3|           6|
# |2015_June_Sunday_...|2015|        6|   Sunday|     June|      7|          19-22|            19|          22|
# +--------------------+----+---------+---------+---------+-------+---------------+--------------+------------+
#
#
# Table: gold_dim_medicament
# +--------+
# |count(1)|
# +--------+
# |  979839|
# +--------+
#
# +---------------+----------+----------+----------------+--------------------+
# |consultation_id|medicament|patient_id|medicament_label|classe_therapeutique|
# +---------------+----------+----------+----------------+--------------------+
# |             26|      NULL|      NULL|            NULL|                NULL|
# |             27|      NULL|      NULL|            NULL|                NULL|
# |             28|      NULL|      NULL|            NULL|                NULL|
# |             44|      NULL|      NULL|            NULL|                NULL|
# |             76|      NULL|      NULL|            NULL|                NULL|
# +---------------+----------+----------+----------------+--------------------+
#
#
# Table: gold_dim_motif_admission
# +--------+
# |count(1)|
# +--------+
# |  636452|
# +--------+
#
# +---------------+--------------------+-----------+--------------------+--------------------+
# |consultation_id|     motif_admission| patient_id|     Catégorie_motif|  Description_longue|
# +---------------+--------------------+-----------+--------------------+--------------------+
# |              1|             armpain|68719476757|   Ostéo-articulaire|     Douleur du bras|
# |              1|             jawpain|68719476757|Ostéo-articulaire...|Douleur de la mâc...|
# |             52|       abdominalpain|68719487425|            Digestif|  Douleur abdominale|
# |            132|abdominalpainpreg...|68719503304|       Gynécologique|Douleur abdominal...|
# |            140|    medicationrefill|68719506012|       Administratif|Renouvellement d’...|
# +---------------+--------------------+-----------+--------------------+--------------------+
#
#
# Table: gold_fact_consultation
# +--------+
# |count(1)|
# +--------+
# |  560486|
# +--------+
#
# +---------------+-----------+-----------+---+------+-----------+-----------------+--------------------+--------------------+---------------------+--------------------+-------------+-------------------+-------------+
# |consultation_id| patient_id|hopital_nom|age|gender|disposition|    previousdispo|       liste_maladie|    liste_medicament|liste_motif_admission|             date_id|nb_chirurgies|nb_visited_urgences|nb_admissions|
# +---------------+-----------+-----------+---+------+-----------+-----------------+--------------------+--------------------+---------------------+--------------------+-------------+-------------------+-------------+
# |              1|68719476757|          B| 57|  MALE|  Discharge|            Admit|[otdxbladdr, vira...|                  []|   [armpain, jawpain]|2014_April_Wednes...|            1|                  3|            1|
# |             12|68719479155|          B| 35|  MALE|  Discharge|No previous dispo|[urinstone, other...|                  []|             [trauma]|2015_June_Saturda...|            3|                  0|            0|
# |             13|68719479274|          B| 21|FEMALE|  Discharge|No previous dispo| [urinstone, asthma]|                  []| [urinarytractinfe...|2016_August_Tuesd...|            1|                  0|            0|
# |             22|68719481593|          A| 21|FEMALE|      Admit|        Discharge|[othergidx, glauc...|[gastrointestinal...| [other, sicklecel...|2014_April_Sunday...|            3|                  1|            0|
# |             47|68719486694|          A| 31|  MALE|  Discharge|        Discharge|[personalitydisor...|                  []| [alcoholintoxicat...|2017_January_Mond...|            0|                  0|            0|
# +---------------+-----------+-----------+---+------+-----------+-----------------+--------------------+--------------------+---------------------+--------------------+-------------+-------------------+-------------+
